# %%
try:
    num1=int(input("enter the first number:"))
    num2=int(input("enter the second number:"))
    result=num1/num2
except ZeroDivisionError:
    print("you can't divide by zero !")
except ValueError:
    print("Error:invalid input .please enter the numeric value ")
else:
    print("Result of division(result)")
finally:
    print("End of the program")
# Out:
# enter the first number: 5
# enter the second number: t
# Error:invalid input .please enter the numeric value
# End of the program

# %%
#regular expresstion##import module
import re #>
text=input("enter the text:")
pattern = r"[a-zA-Z0-9.%+-]+@[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}"
emails = re.findall(pattern, text)##function
print("Emails:",emails)
# Out:
# enter the text: Mubashir123@gmail.com
# Emails: ['Mubashir123@gmail.com']
